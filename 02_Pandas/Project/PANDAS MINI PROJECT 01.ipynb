# %% [markdown]
# ## **1. 📚 Import Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None) # this is to display all the columns in the dataframe
pd.set_option('display.max_rows', None) # this is to display all the rows in the dataframe

# %%
roster_df=pd.read_csv('./data/roster - roster.csv')
roster_df.head()
# Out:
#         ID                    Name     NetID              Email Address  \
# 0  1234567      Barrera Jr., Woody  WXB12345  WOODY.BARRERA_JR@UNIV.EDU
# 1  2345678        Lambert, Malaika  MXL12345   MALAIKA.LAMBERT@UNIV.EDU
# 2  3456789            Joyce, Traci  TXJ12345       TRACI.JOYCE@UNIV.EDU
# 3  4567890      Flower, John Gregg  JGF12345   JOHN.G.2.FLOWER@UNIV.EDU
# 4  8406082  Johnson, Stacy Michael  SMJ00936     STACY.JOHNSON@UNIV.EDU
#
#    Section
# 0        1
# 1        2
# 2        1
# 3        3
# 4        2

# %%
roster_df1=roster_df[['NetID','Email Address','Section']]
roster_df1.set_index('NetID',inplace=True)
roster_df1.head(1)
# Out:
#                       Email Address  Section
# NetID
# WXB12345  WOODY.BARRERA_JR@UNIV.EDU        1

# %%
# Load each quiz file
quiz1 = pd.read_csv('./data/quiz_1_grades.csv', index_col='Email')
quiz2 = pd.read_csv('./data/quiz_2_grades.csv', index_col='Email')
quiz3 = pd.read_csv('./data/quiz_3_grades.csv', index_col='Email')
quiz4 = pd.read_csv('./data/quiz_4_grades.csv', index_col='Email')
quiz5 = pd.read_csv('./data/quiz_5_grades.csv', index_col='Email')

# %%
quiz1.head()
# Out:
#                          Last Name First Name  Grade
# Email
# richard.bennett@univ.edu   Bennett    Richard     10
# timothy.parker@univ.edu     Parker    Timothy      9
# carol.reyes@univ.edu         Reyes      Carol      5
# brooke.powers@univ.edu      Powers     Brooke      6
# michael.taylor@univ.edu     Taylor    Michael      5

# %%
# List of quizzes
quizzes = [quiz1, quiz2, quiz3, quiz4, quiz5]
quiz_names = ['Quiz 1', 'Quiz 2', 'Quiz 3', 'Quiz 4', 'Quiz 5']

for i, quiz in enumerate(quizzes):
    # Drop 'First Name' and 'Last Name' columns
    quiz = quiz.drop(columns=['First Name', 'Last Name'], errors='ignore')
    # Rename remaining columns with the quiz name
    quiz.columns = [f"{col}_{quiz_names[i]}" for col in quiz.columns]
    
    # Remove 'Grade_' prefix from column names
    quiz.columns = [col.replace('Grade_', '') for col in quiz.columns]
    
    quizzes[i] = quiz  # Update the list with the renamed DataFrame

# Merge all quizzes into a single DataFrame
quiz_data = quizzes[0]
for quiz in quizzes[1:]:
    quiz_data = quiz_data.join(quiz, how='outer')

# Display the combined quiz data
quiz_data.head()
# Out:
#                               Quiz 1  Quiz 2  Quiz 3  Quiz 4  Quiz 5
# Email
# aaron.lester@univ.edu              6       9      10       8       8
# adam.cooper@univ.edu               4      10      16       7      12
# alec.curry@univ.edu                9       9       9      12      11
# alexander.rodriguez@univ.edu      11      13      16      11       7
# amber.daniels@univ.edu             7      15      16       5       6

# %%
exam_df=pd.read_csv('./data/hw_exam_grades.csv')
exam_df.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  Homework 3 - Max Points  \
# ...
