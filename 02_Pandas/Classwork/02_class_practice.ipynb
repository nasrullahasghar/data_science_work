# %%
import pandas as pd
import numpy as np

# %%
tuberculosis=pd.read_csv('./data/cdc_tuberculosis.csv',header=1,thousands=',')
tuberculosis
# Out:
#        U.S. jurisdiction  2019  2020  2021  2019.1  2020.1  2021.1
# 0                  Total  8900  7173  7860    2.71    2.16    2.37
# 1                Alabama    87    72    92    1.77    1.43    1.83
# 2                 Alaska    58    58    58    7.91    7.92    7.92
# 3                Arizona   183   136   129    2.51    1.89    1.77
# 4               Arkansas    64    59    69    2.12    1.96    2.28
# 5             California  2111  1706  1750    5.35    4.32    4.46
# 6               Colorado    66    52    58    1.15    0.90    1.00
# 7            Connecticut    67    54    54    1.88    1.50    1.50
# 8               Delaware    18    17    43    1.84    1.71    4.29
# 9   District of Columbia    24    19    19    3.39    2.75    2.84
# 10               Florida   558   412   499    2.60    1.91    2.29
# 11               Georgia   302   221   228    2.84    2.06    2.11
# 12                Hawaii    99    92   106    6.99    6.34    7.35
# ...

# %%
tuberculosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   U.S. jurisdiction  52 non-null     object
#  1   2019               52 non-null     int64
#  2   2020               52 non-null     int64
#  3   2021               52 non-null     int64
#  4   2019.1             52 non-null     float64
#  5   2020.1             52 non-null     float64
#  6   2021.1             52 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.0+ KB

# %%
tuberculosis.sum()
# Out:
# U.S. jurisdiction    TotalAlabamaAlaskaArizonaArkansasCaliforniaCol...
# 2019                                                             17800
# 2020                                                             14346
# 2021                                                             15720
# 2019.1                                                          109.94
# 2020.1                                                           93.09
# 2021.1                                                          102.94
# dtype: object
